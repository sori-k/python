# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('score.csv')
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
x = df['이름'].values
x
# Out:
# array(['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
#       dtype=object)

# %%
y = df['키'].values
y
# Out:
# array([197, 184, 168, 187, 188, 202, 188, 190], dtype=int64)

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #맑은 고딕
matplotlib.rcParams['font.size'] = 15 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용 시 마이너스 글자가 깨지는 현상을 해결

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.show()

# %%
plt.bar(x, y)
plt.title('학생별 키')
plt.show()

# %%
plt.bar(x, y, color='green')
plt.title('학생별 키')
plt.xlabel('이름')
plt.ylabel('키')
plt.show()

# %%
plt.plot(x, y, color='green', label='키')
plt.legend()
plt.title('학생별 키')
plt.xlabel('이름')
plt.ylabel('키')
plt.show()

# %%
plt.figure(figsize=(10, 5), dpi=50) # dpi (해상도)
plt.plot(x, y, color='black', label='키', marker='o', markersize=4, mec='black', mfc='blue', ls='--') # 사이즈는 ms 라고 해도 됨
plt.legend()
plt.title('학생별 키')
plt.xlabel('이름')
plt.ylabel('키')
plt.show()

# %%
kor =df['국어'].values
kor
# Out:
# array([ 90,  40,  80,  40,  15,  80,  55, 100], dtype=int64)

# %%
eng = df['영어'].values
eng
# Out:
# array([ 85,  35,  75,  60,  20, 100,  65,  85], dtype=int64)

# %%
mat = df['수학'].values
mat
# Out:
# array([100,  50,  70,  70,  10,  95,  45,  90], dtype=int64)

# %%
import numpy as np
index = np.arange(8)
index
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
w=0.25
plt.figure(figsize=(10, 5), dpi=50)
plt.bar(index-w, kor, color='#FFCCFF', width=w, label='국어')
plt.bar(index, eng, color='#99FF99', width=w, label='영어')
plt.bar(index+w, mat, color='#FFB266', width=w, label='수학')
plt.legend(ncol=3)
plt.xticks(index, x, rotation=60)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('score.csv', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df2 = df[['이름', '학교', '키', 'SW특기']]
df2
# Out:
#        이름   학교    키        SW특기
# 지원번호
# 1번    채치수  북산고  197      Python
# 2번    정대만  북산고  184        Java
# 3번    송태섭  북산고  168  Javascript
# 4번    서태웅  북산고  187         NaN
# 5번    강백호  북산고  188         NaN
# 6번    변덕규  능남고  202           C
# 7번    황태산  능남고  188      PYTHON
# 8번    윤대협  능남고  190          C#

# %%
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
plt.figure(figsize=(10, 5), dpi=50)
x = df['이름'].values
y = df['국어'].values
plt.bar(x, y)
plt.show()
